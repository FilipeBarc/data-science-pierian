# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.set_style('darkgrid')

# %% [markdown]
# ### Importing data

# %%
df = pd.read_csv('fake_reg.csv')
df
# Out:
#           price     feature1     feature2
# 0    461.527929   999.787558   999.766096
# 1    548.130011   998.861615  1001.042403
# 2    410.297162  1000.070267   998.844015
# 3    540.382220   999.952251  1000.440940
# 4    546.024553  1000.446011  1000.338531
# ..          ...          ...          ...
# 995  476.526078  1000.018988   999.672732
# 996  457.313186   998.855379  1000.020026
# 997  456.720992  1001.451646   998.847606
# 998  403.315576  1000.771023   998.562851
# 999  599.367093   999.232244  1001.451407
#
# [1000 rows x 3 columns]

# %% [markdown]
# ### Creating a pairplot of the data frame

# %%
sns.pairplot(df)

# %% [markdown]
# ### Train test split

# %%
from sklearn.model_selection import train_test_split

# %%
X = df[['feature1','feature2']].values
y = df['price'].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# ### Scaling/normalizing the data

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(X_train)
# Out:
# MinMaxScaler()

# %%
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ### Creating the model using Keras

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation

# %%
X_train.shape
# Out:
# (700, 2)

# %%
model = Sequential()

model.add(Dense(4,activation='relu'))
model.add(Dense(4,activation='relu'))
model.add(Dense(4,activation='relu'))

model.add(Dense(1))

# %% [markdown]
# ### Creating the optimizer and the loss function
#
# Keep in mind what kind of problem you are trying to solve:
#
# #### For a multi-class classification problem
# model.compile(optimizer='rmsprop',
#               loss='categorical_crossentropy',
#               metrics=['accuracy'])
#
# #### For a binary classification problem
# model.compile(optimizer='rmsprop',
#               loss='binary_crossentropy',
#               metrics=['accuracy'])
#
# #### For a mean squared error regression problem
# model.compile(optimizer='rmsprop',
#               loss='mse')

# %%
model.compile(optimizer='rmsprop',loss='mse')

# %% [markdown]
# ### Training the model
#
# Below are some common definitions that are necessary to know and understand to correctly utilize Keras:
#
# Sample: one element of a dataset.
#
#     Example: one image is a sample in a convolutional network
#
#     Example: one audio file is a sample for a speech recognition model
#
# Batch: a set of N samples. The samples in a batch are processed independently, in parallel. If training, a batch results in only one update to the model.A batch generally approximates the distribution of the input data better than a single input. The larger the batch, the better the approximation; however, it is also true that the batch will take longer to process and will still result in only one update. For inference (evaluate/predict), it is recommended to pick a batch size that is as large as you can afford without going out of memory (since larger batches will usually result in faster evaluation/prediction).
#
# Epoch: an arbitrary cutoff, generally defined as "one pass over the entire dataset", used to separate training into distinct phases, which is useful for logging and periodic evaluation.
#
# When using validation_data or validation_split with the fit method of Keras models, evaluation will be run at the end of every epoch.
#
# Within Keras, there is the ability to add callbacks specifically designed to be run at the end of an epoch. Examples of these are learning rate changes and model checkpointing (saving).

# %%
model.fit(X_train,y_train,epochs=250)
# Out:
# Epoch 1/250
# 22/22 [==============================] - 1s 2ms/step - loss: 256905.4219
# Epoch 2/250
# 22/22 [==============================] - 0s 3ms/step - loss: 256762.1875
# Epoch 3/250
# 22/22 [==============================] - 0s 3ms/step - loss: 256672.8906
# Epoch 4/250
# 22/22 [==============================] - 0s 2ms/step - loss: 256624.2500
# Epoch 5/250
# 22/22 [==============================] - 0s 3ms/step - loss: 256582.4531
# Epoch 6/250
# 22/22 [==============================] - 0s 3ms/step - loss: 256539.1094
# Epoch 7/250
# 22/22 [==============================] - 0s 2ms/step - loss: 256495.2656
# Epoch 8/250
# 22/22 [==============================] - 0s 3ms/step - loss: 256448.3438
# Epoch 9/250
# 22/22 [==============================] - 0s 3ms/step - loss: 256384.1406
# Epoch 10/250
# 22/22 [==============================] - 0s 2ms/step - loss: 256294.3281
# Epoch 11/250
# 22/22 [==============================] - 0s 3ms/step - loss: 256199.4062
# Epoch 12/250
# 22/22 [==============================] - 0s 2ms/step - loss: 256099.7031
# Epoch 13/250
# 22/22 [==============================] - 0s 3ms/step - loss: 255988.7031
# Epoch 14/250
# 22/22 [==============================] - 0s 3ms/step - loss: 255861.2812
# Epoch 15/250
# 22/22 [==============================] - 0s 3ms/step - loss: 255713.0938
# Epoch 16/250
# 22/22 [==============================] - 0s 2ms/step - loss: 255537.0938
# Epoch 17/250
# 22/22 [==============================] - 0s 3ms/step - loss: 255329.3750
# Epoch 18/250
# 22/22 [==============================] - 0s 4ms/step - loss: 255085.1406
# Epoch 19/250
# 22/22 [==============================] - 0s 5ms/step - loss: 254799.8906
# Epoch 20/250
# 22/22 [==============================] - 0s 4ms/step - loss: 254469.3281
# Epoch 21/250
# 22/22 [==============================] - 0s 4ms/step - loss: 254090.5156
# Epoch 22/250
# 22/22 [==============================] - 0s 5ms/step - loss: 253665.4219
# Epoch 23/250
# 22/22 [==============================] - 0s 4ms/step - loss: 253188.9375
# Epoch 24/250
# 22/22 [==============================] - 0s 3ms/step - loss: 252656.9219
# Epoch 25/250
# 22/22 [==============================] - 0s 4ms/step - loss: 252069.8438
# Epoch 26/250
# 22/22 [==============================] - 0s 2ms/step - loss: 251419.6562
# Epoch 27/250
# 22/22 [==============================] - 0s 3ms/step - loss: 250705.2500
# Epoch 28/250
# 22/22 [==============================] - 0s 3ms/step - loss: 249918.2812
# Epoch 29/250
# 22/22 [==============================] - 0s 3ms/step - loss: 249061.7656
# Epoch 30/250
# 22/22 [==============================] - 0s 5ms/step - loss: 248123.1562
# Epoch 31/250
# 22/22 [==============================] - 0s 5ms/step - loss: 247102.9219
# Epoch 32/250
# 22/22 [==============================] - 0s 3ms/step - loss: 245998.0156
# Epoch 33/250
# 22/22 [==============================] - 0s 3ms/step - loss: 244796.7812
# Epoch 34/250
# 22/22 [==============================] - 0s 4ms/step - loss: 243500.5312
# Epoch 35/250
# 22/22 [==============================] - 0s 4ms/step - loss: 242106.3281
# Epoch 36/250
# 22/22 [==============================] - 0s 3ms/step - loss: 240605.6406
# Epoch 37/250
# 22/22 [==============================] - 0s 3ms/step - loss: 238997.8750
# Epoch 38/250
# 22/22 [==============================] - 0s 4ms/step - loss: 237271.8125
# Epoch 39/250
# 22/22 [==============================] - 0s 3ms/step - loss: 235428.6406
# Epoch 40/250
# 22/22 [==============================] - 0s 3ms/step - loss: 233459.9531
# Epoch 41/250
# 22/22 [==============================] - 0s 2ms/step - loss: 231368.7344
# Epoch 42/250
# 22/22 [==============================] - 0s 3ms/step - loss: 229153.1406
# Epoch 43/250
# 22/22 [==============================] - 0s 2ms/step - loss: 226788.9375
# Epoch 44/250
# 22/22 [==============================] - 0s 3ms/step - loss: 224287.7656
# Epoch 45/250
# 22/22 [==============================] - 0s 3ms/step - loss: 221638.5156
# Epoch 46/250
# 22/22 [==============================] - 0s 3ms/step - loss: 218846.1875
# Epoch 47/250
# 22/22 [==============================] - 0s 3ms/step - loss: 215914.4219
# Epoch 48/250
# 22/22 [==============================] - 0s 3ms/step - loss: 212832.1094
# Epoch 49/250
# 22/22 [==============================] - 0s 3ms/step - loss: 209581.3438
# Epoch 50/250
# 22/22 [==============================] - 0s 3ms/step - loss: 206172.2500
# Epoch 51/250
# 22/22 [==============================] - 0s 5ms/step - loss: 202600.4531
# Epoch 52/250
# 22/22 [==============================] - 0s 4ms/step - loss: 198876.5469
# Epoch 53/250
# 22/22 [==============================] - 0s 4ms/step - loss: 194963.4219
# Epoch 54/250
# 22/22 [==============================] - 0s 3ms/step - loss: 190926.8438
# Epoch 55/250
# 22/22 [==============================] - 0s 2ms/step - loss: 186703.4688
# Epoch 56/250
# 22/22 [==============================] - 0s 4ms/step - loss: 182313.0312
# Epoch 57/250
# 22/22 [==============================] - 0s 3ms/step - loss: 177766.6562
# Epoch 58/250
# 22/22 [==============================] - 0s 3ms/step - loss: 173037.0938
# Epoch 59/250
# 22/22 [==============================] - 0s 2ms/step - loss: 168181.1094
# Epoch 60/250
# 22/22 [==============================] - 0s 2ms/step - loss: 163159.2500
# Epoch 61/250
# 22/22 [==============================] - 0s 3ms/step - loss: 157977.3906
# Epoch 62/250
# 22/22 [==============================] - 0s 4ms/step - loss: 152654.9062
# Epoch 63/250
# 22/22 [==============================] - 0s 3ms/step - loss: 147203.3594
# Epoch 64/250
# 22/22 [==============================] - 0s 4ms/step - loss: 141592.5312
# Epoch 65/250
# 22/22 [==============================] - 0s 3ms/step - loss: 135861.3438
# Epoch 66/250
# 22/22 [==============================] - 0s 4ms/step - loss: 129997.8594
# Epoch 67/250
# 22/22 [==============================] - 0s 3ms/step - loss: 124017.7344
# Epoch 68/250
# 22/22 [==============================] - 0s 2ms/step - loss: 117988.5156
# Epoch 69/250
# 22/22 [==============================] - 0s 2ms/step - loss: 111863.3906
# Epoch 70/250
# 22/22 [==============================] - 0s 3ms/step - loss: 105654.8438
# Epoch 71/250
# 22/22 [==============================] - 0s 2ms/step - loss: 99374.3906
# Epoch 72/250
# 22/22 [==============================] - 0s 3ms/step - loss: 93077.8750
# Epoch 73/250
# 22/22 [==============================] - 0s 3ms/step - loss: 86754.2812
# Epoch 74/250
# 22/22 [==============================] - 0s 2ms/step - loss: 80456.7188
# Epoch 75/250
# 22/22 [==============================] - 0s 2ms/step - loss: 74167.3516
# Epoch 76/250
# 22/22 [==============================] - 0s 3ms/step - loss: 67958.9062
# Epoch 77/250
# 22/22 [==============================] - 0s 2ms/step - loss: 61817.6289
# Epoch 78/250
# 22/22 [==============================] - 0s 2ms/step - loss: 55770.3320
# Epoch 79/250
# 22/22 [==============================] - 0s 3ms/step - loss: 49792.0742
# Epoch 80/250
# 22/22 [==============================] - 0s 3ms/step - loss: 44051.6523
# Epoch 81/250
# 22/22 [==============================] - 0s 3ms/step - loss: 38516.4609
# Epoch 82/250
# 22/22 [==============================] - 0s 3ms/step - loss: 33226.3867
# Epoch 83/250
# 22/22 [==============================] - 0s 3ms/step - loss: 28163.1035
# Epoch 84/250
# 22/22 [==============================] - 0s 3ms/step - loss: 23437.3477
# Epoch 85/250
# 22/22 [==============================] - 0s 2ms/step - loss: 19107.4492
# Epoch 86/250
# 22/22 [==============================] - 0s 2ms/step - loss: 15170.0674
# Epoch 87/250
# 22/22 [==============================] - 0s 2ms/step - loss: 11671.7461
# Epoch 88/250
# 22/22 [==============================] - 0s 3ms/step - loss: 8691.0068
# Epoch 89/250
# 22/22 [==============================] - 0s 3ms/step - loss: 6256.6636
# Epoch 90/250
# 22/22 [==============================] - 0s 4ms/step - loss: 4376.7007
# Epoch 91/250
# 22/22 [==============================] - 0s 3ms/step - loss: 3110.9905
# Epoch 92/250
# 22/22 [==============================] - 0s 2ms/step - loss: 2425.0613
# Epoch 93/250
# 22/22 [==============================] - 0s 2ms/step - loss: 2165.0654
# Epoch 94/250
# 22/22 [==============================] - 0s 3ms/step - loss: 2105.6667
# Epoch 95/250
# 22/22 [==============================] - 0s 5ms/step - loss: 2072.2649
# Epoch 96/250
# 22/22 [==============================] - 0s 4ms/step - loss: 2037.1957
# Epoch 97/250
# 22/22 [==============================] - 0s 2ms/step - loss: 1999.2096
# Epoch 98/250
# 22/22 [==============================] - 0s 2ms/step - loss: 1960.4615
# Epoch 99/250
# 22/22 [==============================] - 0s 3ms/step - loss: 1919.9158
# Epoch 100/250
# 22/22 [==============================] - 0s 3ms/step - loss: 1890.6407
# Epoch 101/250
# 22/22 [==============================] - 0s 3ms/step - loss: 1856.6750
# Epoch 102/250
# 22/22 [==============================] - 0s 2ms/step - loss: 1822.3439
# Epoch 103/250
# 22/22 [==============================] - 0s 2ms/step - loss: 1788.5382
# Epoch 104/250
# 22/22 [==============================] - 0s 2ms/step - loss: 1756.3237
# Epoch 105/250
# 22/22 [==============================] - 0s 2ms/step - loss: 1725.1500
# Epoch 106/250
# 22/22 [==============================] - 0s 2ms/step - loss: 1696.9343
# Epoch 107/250
# 22/22 [==============================] - 0s 3ms/step - loss: 1665.5454
# Epoch 108/250
# 22/22 [==============================] - 0s 3ms/step - loss: 1632.7312
# Epoch 109/250
# 22/22 [==============================] - 0s 2ms/step - loss: 1600.4247
# Epoch 110/250
# 22/22 [==============================] - 0s 2ms/step - loss: 1569.3195
# Epoch 111/250
# 22/22 [==============================] - 0s 3ms/step - loss: 1534.2257
# Epoch 112/250
# 22/22 [==============================] - 0s 3ms/step - loss: 1503.8732
# Epoch 113/250
# 22/22 [==============================] - 0s 4ms/step - loss: 1471.9799
# Epoch 114/250
# 22/22 [==============================] - 0s 3ms/step - loss: 1437.1012
# Epoch 115/250
# 22/22 [==============================] - 0s 3ms/step - loss: 1404.4908
# Epoch 116/250
# 22/22 [==============================] - 0s 3ms/step - loss: 1370.2233
# Epoch 117/250
# 22/22 [==============================] - 0s 4ms/step - loss: 1338.5764
# Epoch 118/250
# 22/22 [==============================] - 0s 3ms/step - loss: 1307.5061
# Epoch 119/250
# 22/22 [==============================] - 0s 3ms/step - loss: 1281.4924
# Epoch 120/250
# 22/22 [==============================] - 0s 5ms/step - loss: 1254.1169
# Epoch 121/250
# 22/22 [==============================] - 0s 5ms/step - loss: 1228.9176
# Epoch 122/250
# 22/22 [==============================] - 0s 4ms/step - loss: 1201.7289
# Epoch 123/250
# 22/22 [==============================] - 0s 4ms/step - loss: 1172.4233
# Epoch 124/250
# 22/22 [==============================] - 0s 4ms/step - loss: 1138.2627
# Epoch 125/250
# 22/22 [==============================] - 0s 4ms/step - loss: 1109.0909
# Epoch 126/250
# 22/22 [==============================] - 0s 3ms/step - loss: 1076.8276
# Epoch 127/250
# 22/22 [==============================] - 0s 3ms/step - loss: 1051.5266
# Epoch 128/250
# 22/22 [==============================] - 0s 5ms/step - loss: 1021.6482
# Epoch 129/250
# 22/22 [==============================] - 0s 10ms/step - loss: 1001.3926
# Epoch 130/250
# 22/22 [==============================] - 0s 3ms/step - loss: 977.1920
# Epoch 131/250
# 22/22 [==============================] - 0s 3ms/step - loss: 947.6468
# Epoch 132/250
# 22/22 [==============================] - 0s 3ms/step - loss: 915.4803
# Epoch 133/250
# 22/22 [==============================] - 0s 3ms/step - loss: 886.1126
# Epoch 134/250
# 22/22 [==============================] - 0s 3ms/step - loss: 857.3194
# Epoch 135/250
# 22/22 [==============================] - 0s 3ms/step - loss: 828.4030
# Epoch 136/250
# 22/22 [==============================] - 0s 3ms/step - loss: 806.0477
# Epoch 137/250
# 22/22 [==============================] - 0s 3ms/step - loss: 779.6146
# Epoch 138/250
# 22/22 [==============================] - 0s 2ms/step - loss: 754.3087
# Epoch 139/250
# 22/22 [==============================] - 0s 3ms/step - loss: 730.5611
# Epoch 140/250
# 22/22 [==============================] - 0s 4ms/step - loss: 707.1071
# Epoch 141/250
# 22/22 [==============================] - 0s 3ms/step - loss: 683.7925
# Epoch 142/250
# 22/22 [==============================] - 0s 3ms/step - loss: 656.1649
# Epoch 143/250
# 22/22 [==============================] - 0s 3ms/step - loss: 630.7746
# Epoch 144/250
# 22/22 [==============================] - 0s 3ms/step - loss: 606.4276
# Epoch 145/250
# 22/22 [==============================] - 0s 3ms/step - loss: 581.0998
# Epoch 146/250
# 22/22 [==============================] - 0s 3ms/step - loss: 561.3712
# Epoch 147/250
# 22/22 [==============================] - 0s 3ms/step - loss: 539.3395
# Epoch 148/250
# 22/22 [==============================] - 0s 2ms/step - loss: 521.2624
# Epoch 149/250
# 22/22 [==============================] - 0s 3ms/step - loss: 500.0809
# Epoch 150/250
# 22/22 [==============================] - 0s 3ms/step - loss: 479.8234
# Epoch 151/250
# 22/22 [==============================] - 0s 4ms/step - loss: 459.0610
# Epoch 152/250
# 22/22 [==============================] - 0s 3ms/step - loss: 439.5603
# Epoch 153/250
# 22/22 [==============================] - 0s 3ms/step - loss: 423.1492
# Epoch 154/250
# 22/22 [==============================] - 0s 3ms/step - loss: 405.4289
# Epoch 155/250
# 22/22 [==============================] - 0s 3ms/step - loss: 387.9566
# Epoch 156/250
# 22/22 [==============================] - 0s 3ms/step - loss: 371.8812
# Epoch 157/250
# 22/22 [==============================] - 0s 3ms/step - loss: 352.3985
# Epoch 158/250
# 22/22 [==============================] - 0s 3ms/step - loss: 335.5328
# Epoch 159/250
# 22/22 [==============================] - 0s 3ms/step - loss: 317.1292
# Epoch 160/250
# 22/22 [==============================] - 0s 4ms/step - loss: 301.0696
# Epoch 161/250
# 22/22 [==============================] - 0s 2ms/step - loss: 284.4713
# Epoch 162/250
# 22/22 [==============================] - 0s 3ms/step - loss: 268.0495
# Epoch 163/250
# 22/22 [==============================] - 0s 3ms/step - loss: 254.1382
# Epoch 164/250
# 22/22 [==============================] - 0s 3ms/step - loss: 240.0835
# Epoch 165/250
# 22/22 [==============================] - 0s 4ms/step - loss: 227.2661
# Epoch 166/250
# 22/22 [==============================] - 0s 3ms/step - loss: 213.5587
# Epoch 167/250
# 22/22 [==============================] - 0s 3ms/step - loss: 200.3951
# Epoch 168/250
# 22/22 [==============================] - 0s 3ms/step - loss: 188.2398
# Epoch 169/250
# 22/22 [==============================] - 0s 3ms/step - loss: 177.0014
# Epoch 170/250
# 22/22 [==============================] - 0s 3ms/step - loss: 165.6398
# Epoch 171/250
# 22/22 [==============================] - 0s 3ms/step - loss: 154.5361
# Epoch 172/250
# 22/22 [==============================] - 0s 3ms/step - loss: 145.7433
# Epoch 173/250
# 22/22 [==============================] - 0s 3ms/step - loss: 136.9648
# Epoch 174/250
# 22/22 [==============================] - 0s 4ms/step - loss: 127.6668
# Epoch 175/250
# 22/22 [==============================] - 0s 3ms/step - loss: 117.6553
# Epoch 176/250
# 22/22 [==============================] - 0s 3ms/step - loss: 108.9736
# Epoch 177/250
# 22/22 [==============================] - 0s 4ms/step - loss: 100.6856
# Epoch 178/250
# 22/22 [==============================] - 0s 4ms/step - loss: 93.7519
# Epoch 179/250
# 22/22 [==============================] - 0s 3ms/step - loss: 86.8983
# Epoch 180/250
# 22/22 [==============================] - 0s 4ms/step - loss: 81.6168
# Epoch 181/250
# 22/22 [==============================] - 0s 4ms/step - loss: 75.0049
# Epoch 182/250
# 22/22 [==============================] - 0s 6ms/step - loss: 69.1049
# Epoch 183/250
# 22/22 [==============================] - 0s 5ms/step - loss: 63.6132
# Epoch 184/250
# 22/22 [==============================] - 0s 3ms/step - loss: 59.8128
# Epoch 185/250
# 22/22 [==============================] - 0s 5ms/step - loss: 55.3082
# Epoch 186/250
# 22/22 [==============================] - 0s 4ms/step - loss: 50.9788
# Epoch 187/250
# 22/22 [==============================] - 0s 3ms/step - loss: 47.4290
# Epoch 188/250
# 22/22 [==============================] - 0s 4ms/step - loss: 44.0181
# Epoch 189/250
# 22/22 [==============================] - 0s 5ms/step - loss: 41.2077
# Epoch 190/250
# 22/22 [==============================] - 0s 4ms/step - loss: 38.0462
# Epoch 191/250
# 22/22 [==============================] - 0s 3ms/step - loss: 36.6119
# Epoch 192/250
# 22/22 [==============================] - 0s 4ms/step - loss: 34.4767
# Epoch 193/250
# 22/22 [==============================] - 0s 3ms/step - loss: 33.2387
# Epoch 194/250
# 22/22 [==============================] - 0s 3ms/step - loss: 31.4907
# Epoch 195/250
# 22/22 [==============================] - 0s 3ms/step - loss: 30.2499
# Epoch 196/250
# 22/22 [==============================] - 0s 3ms/step - loss: 29.4881
# Epoch 197/250
# 22/22 [==============================] - 0s 4ms/step - loss: 28.4292
# Epoch 198/250
# 22/22 [==============================] - 0s 4ms/step - loss: 28.2791
# Epoch 199/250
# 22/22 [==============================] - 0s 3ms/step - loss: 26.7483
# Epoch 200/250
# 22/22 [==============================] - 0s 3ms/step - loss: 26.8618
# Epoch 201/250
# 22/22 [==============================] - 0s 4ms/step - loss: 26.1658
# Epoch 202/250
# 22/22 [==============================] - 0s 5ms/step - loss: 26.3128
# Epoch 203/250
# 22/22 [==============================] - 0s 3ms/step - loss: 25.8810
# Epoch 204/250
# 22/22 [==============================] - 0s 3ms/step - loss: 25.3403
# Epoch 205/250
# 22/22 [==============================] - 0s 3ms/step - loss: 25.1154
# Epoch 206/250
# 22/22 [==============================] - 0s 4ms/step - loss: 24.6778
# Epoch 207/250
# 22/22 [==============================] - 0s 4ms/step - loss: 24.8800
# Epoch 208/250
# 22/22 [==============================] - 0s 3ms/step - loss: 24.9326
# Epoch 209/250
# 22/22 [==============================] - 0s 4ms/step - loss: 24.6256
# Epoch 210/250
# 22/22 [==============================] - 0s 5ms/step - loss: 24.6183
# Epoch 211/250
# 22/22 [==============================] - 0s 4ms/step - loss: 24.8625
# Epoch 212/250
# 22/22 [==============================] - 0s 3ms/step - loss: 24.5152
# Epoch 213/250
# 22/22 [==============================] - 0s 3ms/step - loss: 24.2341
# Epoch 214/250
# 22/22 [==============================] - 0s 3ms/step - loss: 24.6347
# Epoch 215/250
# 22/22 [==============================] - 0s 4ms/step - loss: 23.9893
# Epoch 216/250
# 22/22 [==============================] - 0s 4ms/step - loss: 24.7457
# Epoch 217/250
# 22/22 [==============================] - 0s 3ms/step - loss: 24.5406
# Epoch 218/250
# 22/22 [==============================] - 0s 3ms/step - loss: 24.1490
# Epoch 219/250
# 22/22 [==============================] - 0s 3ms/step - loss: 24.6883
# Epoch 220/250
# 22/22 [==============================] - 0s 3ms/step - loss: 24.0226
# Epoch 221/250
# 22/22 [==============================] - 0s 3ms/step - loss: 24.2941
# Epoch 222/250
# 22/22 [==============================] - 0s 3ms/step - loss: 24.4258
# Epoch 223/250
# 22/22 [==============================] - 0s 4ms/step - loss: 24.5084
# Epoch 224/250
# 22/22 [==============================] - 0s 4ms/step - loss: 24.1559
# Epoch 225/250
# 22/22 [==============================] - 0s 3ms/step - loss: 24.3615
# Epoch 226/250
# 22/22 [==============================] - 0s 4ms/step - loss: 24.3203
# Epoch 227/250
# 22/22 [==============================] - 0s 4ms/step - loss: 24.2857
# Epoch 228/250
# 22/22 [==============================] - 0s 4ms/step - loss: 24.0682
# Epoch 229/250
# 22/22 [==============================] - 0s 4ms/step - loss: 24.0994
# Epoch 230/250
# 22/22 [==============================] - 0s 3ms/step - loss: 24.3043
# Epoch 231/250
# 22/22 [==============================] - 0s 3ms/step - loss: 24.2467
# Epoch 232/250
# 22/22 [==============================] - 0s 4ms/step - loss: 24.4174
# Epoch 233/250
# 22/22 [==============================] - 0s 4ms/step - loss: 24.6068
# Epoch 234/250
# 22/22 [==============================] - 0s 3ms/step - loss: 23.8719
# Epoch 235/250
# 22/22 [==============================] - 0s 4ms/step - loss: 24.1508
# Epoch 236/250
# 22/22 [==============================] - 0s 5ms/step - loss: 24.2270
# Epoch 237/250
# 22/22 [==============================] - 0s 4ms/step - loss: 24.7328
# Epoch 238/250
# 22/22 [==============================] - 0s 3ms/step - loss: 24.1355
# Epoch 239/250
# 22/22 [==============================] - 0s 4ms/step - loss: 24.6669
# Epoch 240/250
# 22/22 [==============================] - 0s 3ms/step - loss: 24.3120
# Epoch 241/250
# 22/22 [==============================] - 0s 7ms/step - loss: 24.6685
# Epoch 242/250
# 22/22 [==============================] - 0s 4ms/step - loss: 24.1671
# Epoch 243/250
# 22/22 [==============================] - 0s 3ms/step - loss: 23.9756
# Epoch 244/250
# 22/22 [==============================] - 0s 2ms/step - loss: 24.2628
# Epoch 245/250
# 22/22 [==============================] - 0s 2ms/step - loss: 24.2207
# Epoch 246/250
# 22/22 [==============================] - 0s 5ms/step - loss: 24.2990
# Epoch 247/250
# 22/22 [==============================] - 0s 4ms/step - loss: 24.4065
# Epoch 248/250
# 22/22 [==============================] - 0s 5ms/step - loss: 24.0419
# Epoch 249/250
# 22/22 [==============================] - 0s 6ms/step - loss: 24.3647
# Epoch 250/250
# 22/22 [==============================] - 0s 4ms/step - loss: 24.5001

# %% [markdown]
# ### Checking the historical losses

# %%
df_mh = pd.DataFrame(model.history.history)
df_mh
# Out:
#               loss
# 0    256905.421875
# 1    256762.187500
# 2    256672.890625
# 3    256624.250000
# 4    256582.453125
# ..             ...
# 245      24.298990
# 246      24.406450
# 247      24.041933
# 248      24.364691
# 249      24.500061
#
# [250 rows x 1 columns]

# %%
df_mh.plot()
# Out:
# <Axes: >

# %% [markdown]
# ### Testing the model in a new data set

# %%
model.evaluate(X_test,y_test,verbose=0)
# Out:
# 25.096336364746094

# %%
model.evaluate(X_train,y_train,verbose=0)
# Out:
# 24.44741439819336

# %% [markdown]
# ### Getting predictions

# %%
pred = model.predict(X_test)
# Out:
# 10/10 [==============================] - 0s 3ms/step

# %% [markdown]
# ### Comparing the pred with y_test

# %%
pred_df = pd.DataFrame(y_test,columns=['True Y'])

# %%
pred_df['pred'] = pred

# %%
pred_df
# Out:
#          True Y        pred
# 0    402.296319  404.807251
# 1    624.156198  622.962708
# 2    582.455066  591.570557
# 3    578.588606  571.666687
# 4    371.224104  366.141602
# ..          ...         ...
# 295  525.704657  528.504822
# 296  502.909473  514.746338
# 297  612.727910  609.081726
# 298  417.569725  416.471924
# 299  410.538250  410.387421
#
# [300 rows x 2 columns]

# %% [markdown]
# ### Ploting the label and predictions

# %%
sns.scatterplot(y='True Y',x='pred',data=pred_df)
sns.scatterplot(x='True Y',y='pred',data=pred_df)
# Out:
# <Axes: xlabel='pred', ylabel='True Y'>

# %% [markdown]
# ### Getting mean absolute error, mean squared error and root mean squared error
#
# Analysing the mean absolute error and the mean of the original data frame you can conclude that the MAB is less than
# 1% of the mean value, what means that is a good prediction

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
mean_absolute_error(y_test,pred)
# Out:
# 4.009941975077195

# %%
df.describe()
# Out:
#              price     feature1     feature2
# count  1000.000000  1000.000000  1000.000000
# mean    498.673029  1000.014171   999.979847
# std      93.785431     0.974018     0.948330
# min     223.346793   997.058347   996.995651
# 25%     433.025732   999.332068   999.316106
# 50%     502.382117  1000.009915  1000.002243
# 75%     564.921588  1000.637580  1000.645380
# max     774.407854  1003.207934  1002.666308

# %%
mean_squared_error(y_test,pred)
# Out:
# 25.09633910623738

# %%
### Root mean squared error
mean_squared_error(y_test,pred)**0.5
# Out:
# 5.009624647240288

# %% [markdown]
# ### Testing the model with a new created value

# %%
new_val = [[998,1000]]
new_val = scaler.transform(new_val)
model.predict(new_val)
# Out:
# 1/1 [==============================] - 0s 59ms/step
# array([[419.1894]], dtype=float32)

# %% [markdown]
# ### Saving the model

# %%
from tensorflow.keras.models import load_model

# %%
model.save('values_predictor.h5')

# %% [markdown]
# ### Using model in a new notebook

# %%
new_model = load_model('values_predictor.h5')

# %%
new_val2 = [[1000,998]]
new_val2 = scaler.transform(new_val)

# %%
new_model.predict(new_val2)
# Out:
# 1/1 [==============================] - 0s 158ms/step
# array([[1842.7474]], dtype=float32)
