# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_style('darkgrid')

# %% [markdown]
# ### Importing data

# %%
df = pd.read_csv('cancer_classification.csv')
df
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0             0.27760         0.30010              0.14710         0.2419
# 1             0.07864         0.08690              0.07017         0.1812
# 2             0.15990         0.19740              0.12790         0.2069
# 3             0.28390         0.24140              0.10520         0.2597
# 4             0.13280         0.19800              0.10430         0.1809
# ..                ...             ...                  ...            ...
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362         0.00000              0.00000         0.1587
#
#      mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                   0.07871  ...          17.33           184.60      2019.0
# 1                   0.05667  ...          23.41           158.80      1956.0
# 2                   0.05999  ...          25.53           152.50      1709.0
# 3                   0.09744  ...          26.50            98.87       567.7
# 4                   0.05883  ...          16.67           152.20      1575.0
# ..                      ...  ...            ...              ...         ...
# 564                 0.05623  ...          26.40           166.10      2027.0
# 565                 0.05533  ...          38.25           155.00      1731.0
# 566                 0.05648  ...          34.12           126.70      1124.0
# 567                 0.07016  ...          39.42           184.60      1821.0
# 568                 0.05884  ...          30.37            59.16       268.6
#
#      worst smoothness  worst compactness  worst concavity  \
# 0             0.16220            0.66560           0.7119
# 1             0.12380            0.18660           0.2416
# 2             0.14440            0.42450           0.4504
# 3             0.20980            0.86630           0.6869
# 4             0.13740            0.20500           0.4000
# ..                ...                ...              ...
# 564           0.14100            0.21130           0.4107
# 565           0.11660            0.19220           0.3215
# 566           0.11390            0.30940           0.3403
# 567           0.16500            0.86810           0.9387
# 568           0.08996            0.06444           0.0000
#
#      worst concave points  worst symmetry  worst fractal dimension  \
# 0                  0.2654          0.4601                  0.11890
# 1                  0.1860          0.2750                  0.08902
# 2                  0.2430          0.3613                  0.08758
# 3                  0.2575          0.6638                  0.17300
# 4                  0.1625          0.2364                  0.07678
# ..                    ...             ...                      ...
# 564                0.2216          0.2060                  0.07115
# 565                0.1628          0.2572                  0.06637
# 566                0.1418          0.2218                  0.07820
# 567                0.2650          0.4087                  0.12400
# 568                0.0000          0.2871                  0.07039
#
#      benign_0__mal_1
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ..               ...
# 564                0
# 565                0
# 566                0
# 567                0
# 568                1
#
# [569 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean radius              569 non-null    float64
#  1   mean texture             569 non-null    float64
#  2   mean perimeter           569 non-null    float64
#  3   mean area                569 non-null    float64
#  4   mean smoothness          569 non-null    float64
#  5   mean compactness         569 non-null    float64
#  6   mean concavity           569 non-null    float64
#  7   mean concave points      569 non-null    float64
#  8   mean symmetry            569 non-null    float64
#  9   mean fractal dimension   569 non-null    float64
#  10  radius error             569 non-null    float64
#  11  texture error            569 non-null    float64
#  12  perimeter error          569 non-null    float64
#  13  area error               569 non-null    float64
#  14  smoothness error         569 non-null    float64
#  15  compactness error        569 non-null    float64
#  16  concavity error          569 non-null    float64
#  17  concave points error     569 non-null    float64
#  18  symmetry error           569 non-null    float64
#  19  fractal dimension error  569 non-null    float64
#  20  worst radius             569 non-null    float64
#  21  worst texture            569 non-null    float64
#  22  worst perimeter          569 non-null    float64
#  23  worst area               569 non-null    float64
#  24  worst smoothness         569 non-null    float64
#  25  worst compactness        569 non-null    float64
#  26  worst concavity          569 non-null    float64
#  27  worst concave points     569 non-null    float64
#  28  worst symmetry           569 non-null    float64
#  29  worst fractal dimension  569 non-null    float64
#  30  benign_0__mal_1          569 non-null    int64
# dtypes: float64(30), int64(1)
# memory usage: 137.9 KB

# %%
df.describe()
# Out:
#        mean radius  mean texture  mean perimeter    mean area  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean smoothness  mean compactness  mean concavity  mean concave points  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# 25%           0.086370          0.064920        0.029560             0.020310
# 50%           0.095870          0.092630        0.061540             0.033500
# 75%           0.105300          0.130400        0.130700             0.074000
# max           0.163400          0.345400        0.426800             0.201200
#
#        mean symmetry  mean fractal dimension  ...  worst texture  \
# count     569.000000              569.000000  ...     569.000000
# mean        0.181162                0.062798  ...      25.677223
# std         0.027414                0.007060  ...       6.146258
# min         0.106000                0.049960  ...      12.020000
# 25%         0.161900                0.057700  ...      21.080000
# 50%         0.179200                0.061540  ...      25.410000
# 75%         0.195700                0.066120  ...      29.720000
# max         0.304000                0.097440  ...      49.540000
#
#        worst perimeter   worst area  worst smoothness  worst compactness  \
# count       569.000000   569.000000        569.000000         569.000000
# mean        107.261213   880.583128          0.132369           0.254265
# std          33.602542   569.356993          0.022832           0.157336
# min          50.410000   185.200000          0.071170           0.027290
# 25%          84.110000   515.300000          0.116600           0.147200
# 50%          97.660000   686.500000          0.131300           0.211900
# 75%         125.400000  1084.000000          0.146000           0.339100
# max         251.200000  4254.000000          0.222600           1.058000
#
#        worst concavity  worst concave points  worst symmetry  \
# count       569.000000            569.000000      569.000000
# mean          0.272188              0.114606        0.290076
# std           0.208624              0.065732        0.061867
# min           0.000000              0.000000        0.156500
# 25%           0.114500              0.064930        0.250400
# 50%           0.226700              0.099930        0.282200
# 75%           0.382900              0.161400        0.317900
# max           1.252000              0.291000        0.663800
#
#        worst fractal dimension  benign_0__mal_1
# count               569.000000       569.000000
# mean                  0.083946         0.627417
# std                   0.018061         0.483918
# min                   0.055040         0.000000
# 25%                   0.071460         0.000000
# 50%                   0.080040         1.000000
# 75%                   0.092080         1.000000
# max                   0.207500         1.000000
#
# [8 rows x 31 columns]

# %% [markdown]
# ### Plotting data
# as this is a classification problem, best thing to do is create a countplot to analyze the label to check if it is well balanced

# %%
sns.countplot(x='benign_0__mal_1',data=df)
# Out:
# <Axes: xlabel='benign_0__mal_1', ylabel='count'>

# %% [markdown]
# ### Checking the label correlation

# %%
df.corr()['benign_0__mal_1'][:-1].sort_values().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# ### Train, test, split

# %%
from sklearn.model_selection import train_test_split
X = df.drop('benign_0__mal_1',axis=1)
y = df['benign_0__mal_1']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=101)

# %% [markdown]
# ### Scaling/normalizing data

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.fit_transform(X_test)

# %% [markdown]
# ### Creating the model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
# Out:
# 2023-06-21 17:14:18.821888: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
X_train.shape
# Out:
# (426, 30)

# %%
early_stop = EarlyStopping(monitor='val_loss',mode='min',verbose=1,patience=20)

# %%
model = Sequential()

model.add(Dense(30,activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(15,activation='relu'))
model.add(Dropout(0.5))

# Binary Classification
model.add(Dense(1,activation='sigmoid'))

model.compile(loss='binary_crossentropy',optimizer='adam')
# Out:
# 2023-06-21 17:14:24.144809: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### Training the model

# %%
model.fit(X_train,y_train,epochs=600,validation_data=(X_test,y_test),callbacks=[early_stop])
# Out:
# Epoch 1/600
# 14/14 [==============================] - 1s 18ms/step - loss: 0.7139 - val_loss: 0.6699
# Epoch 2/600
# 14/14 [==============================] - 0s 6ms/step - loss: 0.7047 - val_loss: 0.6543
# Epoch 3/600
# 14/14 [==============================] - 0s 8ms/step - loss: 0.6709 - val_loss: 0.6422
# Epoch 4/600
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6622 - val_loss: 0.6294
# Epoch 5/600
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6569 - val_loss: 0.6108
# Epoch 6/600
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6171 - val_loss: 0.5847
# Epoch 7/600
# 14/14 [==============================] - 0s 6ms/step - loss: 0.5949 - val_loss: 0.5494
# Epoch 8/600
# 14/14 [==============================] - 0s 5ms/step - loss: 0.5802 - val_loss: 0.5064
# Epoch 9/600
# 14/14 [==============================] - 0s 6ms/step - loss: 0.5763 - val_loss: 0.4707
# Epoch 10/600
# 14/14 [==============================] - 0s 5ms/step - loss: 0.5246 - val_loss: 0.4288
# Epoch 11/600
# 14/14 [==============================] - 0s 6ms/step - loss: 0.4902 - val_loss: 0.3867
# Epoch 12/600
# 14/14 [==============================] - 0s 5ms/step - loss: 0.4851 - val_loss: 0.3548
# Epoch 13/600
# 14/14 [==============================] - 0s 6ms/step - loss: 0.4347 - val_loss: 0.3230
# Epoch 14/600
# 14/14 [==============================] - 0s 6ms/step - loss: 0.4290 - val_loss: 0.2969
# Epoch 15/600
# 14/14 [==============================] - 0s 5ms/step - loss: 0.3917 - val_loss: 0.2753
# Epoch 16/600
# 14/14 [==============================] - 0s 7ms/step - loss: 0.3765 - val_loss: 0.2560
# Epoch 17/600
# 14/14 [==============================] - 0s 8ms/step - loss: 0.3544 - val_loss: 0.2364
# Epoch 18/600
# 14/14 [==============================] - 0s 6ms/step - loss: 0.3224 - val_loss: 0.2255
# Epoch 19/600
# 14/14 [==============================] - 0s 6ms/step - loss: 0.3440 - val_loss: 0.2256
# Epoch 20/600
# 14/14 [==============================] - 0s 5ms/step - loss: 0.3463 - val_loss: 0.2066
# Epoch 21/600
# 14/14 [==============================] - 0s 6ms/step - loss: 0.3006 - val_loss: 0.2024
# Epoch 22/600
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2998 - val_loss: 0.1944
# Epoch 23/600
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2987 - val_loss: 0.1860
# Epoch 24/600
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2862 - val_loss: 0.1824
# Epoch 25/600
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2525 - val_loss: 0.1823
# Epoch 26/600
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2828 - val_loss: 0.1911
# Epoch 27/600
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2602 - val_loss: 0.1730
# Epoch 28/600
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2304 - val_loss: 0.1713
# Epoch 29/600
# 14/14 [==============================] - 0s 7ms/step - loss: 0.2377 - val_loss: 0.1913
# Epoch 30/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.2212 - val_loss: 0.1637
# Epoch 31/600
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2197 - val_loss: 0.1527
# Epoch 32/600
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2054 - val_loss: 0.1663
# Epoch 33/600
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2055 - val_loss: 0.1587
# Epoch 34/600
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2225 - val_loss: 0.1408
# Epoch 35/600
# 14/14 [==============================] - 0s 7ms/step - loss: 0.2142 - val_loss: 0.1647
# Epoch 36/600
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1892 - val_loss: 0.1627
# Epoch 37/600
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1987 - val_loss: 0.1590
# Epoch 38/600
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1967 - val_loss: 0.1473
# Epoch 39/600
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1951 - val_loss: 0.1373
# Epoch 40/600
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1888 - val_loss: 0.1678
# Epoch 41/600
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1679 - val_loss: 0.1747
# Epoch 42/600
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1935 - val_loss: 0.1523
# Epoch 43/600
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1790 - val_loss: 0.1416
# Epoch 44/600
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1562 - val_loss: 0.1595
# Epoch 45/600
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1640 - val_loss: 0.1464
# Epoch 46/600
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1743 - val_loss: 0.1566
# Epoch 47/600
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1797 - val_loss: 0.1660
# Epoch 48/600
# 14/14 [==============================] - 0s 7ms/step - loss: 0.1546 - val_loss: 0.1580
# Epoch 49/600
# 14/14 [==============================] - 0s 7ms/step - loss: 0.1673 - val_loss: 0.2039
# Epoch 50/600
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1468 - val_loss: 0.1461
# Epoch 51/600
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1793 - val_loss: 0.1522
# Epoch 52/600
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1325 - val_loss: 0.1980
# Epoch 53/600
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1593 - val_loss: 0.1592
# Epoch 54/600
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1478 - val_loss: 0.1952
# Epoch 55/600
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1444 - val_loss: 0.1792
# Epoch 56/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1634 - val_loss: 0.1685
# Epoch 57/600
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1565 - val_loss: 0.1913
# Epoch 58/600
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1405 - val_loss: 0.1690
# Epoch 59/600
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1436 - val_loss: 0.1783
# Epoch 59: early stopping

# %%
loss = pd.DataFrame(model.history.history)

# %%
loss.plot()
# Out:
# <Axes: >

# %% [markdown]
# ### Predicting

# %%
pred = (model.predict(X_test) > 0.5).astype("int32")
# Out:
# 5/5 [==============================] - 0s 2ms/step

# %% [markdown]
# ### Creating a class report and a conf matrix

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y_test,pred))
print('\n')
print(confusion_matrix(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.98      0.91        55
#            1       0.99      0.89      0.93        88
#
#     accuracy                           0.92       143
#    macro avg       0.92      0.93      0.92       143
# weighted avg       0.93      0.92      0.92       143
#
#
#
# [[54  1]
#  [10 78]]
