# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Importing data

# %%
df1 = pd.read_csv('df1',index_col=0)
df1
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436
# ...              ...       ...       ...       ...
# 2002-09-22  1.013897 -0.288680 -0.342295 -0.638537
# 2002-09-23 -0.642659 -0.104725 -0.631829 -0.909483
# 2002-09-24  0.370136  0.233219  0.535897 -1.552605
# 2002-09-25  0.183339  1.285783 -1.052593 -2.565844
# 2002-09-26  0.775133 -0.850374  0.486728 -1.053427
#
# [1000 rows x 4 columns]

# %%
df2 = pd.read_csv('df2')
df2
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008
# 5  0.286043  0.593465  0.907307  0.637898
# 6  0.430436  0.166230  0.469383  0.497701
# 7  0.312296  0.502823  0.806609  0.850519
# 8  0.187765  0.997075  0.895955  0.530390
# 9  0.908162  0.232726  0.414138  0.432007

# %% [markdown]
# ### Histogram plot

# %%
df1['A'].hist(bins=30,lw=1,edgecolor='black')
# Out:
# <Axes: >

# %%
df1['A'].plot(kind='hist',edgecolor='black')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ### Area plot

# %%
df2.plot.area(alpha=0.4)
# Out:
# <Axes: >

# %% [markdown]
# ### Bar plot

# %%
df2.plot.bar(alpha=0.5)
# Out:
# <Axes: >

# %%
df2.plot.bar(alpha=0.5,stacked=True)
plt.legend(loc='center left',bbox_to_anchor=(1.0,0.5))

# %% [markdown]
# ### Line plot

# %%
df1['B'].plot.line(figsize=(10,3))
# Out:
# <Axes: >

# %% [markdown]
# ### Scatter plot

# %%
df1.plot.scatter(x='A',y='B',s=50,edgecolor='black',figsize=(12,3),c='red')
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A',y='B',s=df1['C']*100,edgecolor='black')
# Out:
# /Users/filipebarcellos/anaconda3/lib/python3.10/site-packages/matplotlib/collections.py:963: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <Axes: xlabel='A', ylabel='B'>

# %% [markdown]
# ### Box plots

# %%
df2.plot.box(showmeans=True,meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"3"})
# Out:
# <Axes: >

# %% [markdown]
# ### Hexbin plot

# %%
df = pd.DataFrame(np.random.randn(1000,2),columns=['a','b'])
df
# Out:
#             a         b
# 0   -1.871860  0.337464
# 1    0.608300  0.548070
# 2    1.666583 -0.798957
# 3    0.344908 -1.061434
# 4    0.065683  0.568271
# ..        ...       ...
# 995  0.902817 -0.309414
# 996  1.307139  2.123461
# 997 -0.674975 -1.138391
# 998  0.474964 -1.438661
# 999  0.421007 -2.054121
#
# [1000 rows x 2 columns]

# %%
df.plot.hexbin(x='a',y='b',gridsize=25,cmap='Greys')
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %% [markdown]
# ### KDE plot

# %%
df2.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# ### GGPLOT
#
# http://matplotlib.org/gallery.html#style_sheets

# %%
plt.style.use('ggplot')

# %%
df1['A'].plot(kind='hist',edgecolor='black')
# Out:
# <Axes: ylabel='Frequency'>
